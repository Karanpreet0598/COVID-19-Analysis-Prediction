# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import pandas as pd

# %%
url = "https://www.worldometers.info/coronavirus/"

page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
tables = soup.find("table")

# %%
table = tables
tab_data = [[cell.text for cell in row.find_all(["th","td"])]
                        for row in table.find_all("tr")]
df = pd.DataFrame(tab_data)

# %%
df.drop([1,2,3,4,5,6,7,8], inplace = True)

# %%
df.drop([224,225,226,227,228,229,230,231], inplace = True)

# %%
df
# Out:
#        0                      1           2         3            4          5  \
# 0      #          Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 9      1                    USA   5,869,507   +28,079     180,555        +381
# 10     2                 Brazil   3,605,783   +23,085     114,744        +467
# 11     3                  India   3,105,185   +61,749      57,692        +846
# 12     4                 Russia     956,749    +4,852      16,383         +73
# ..   ...                    ...         ...       ...          ...        ...
# 219  211         Western Sahara          10                     1
# 220  212             MS Zaandam           9                     2
# 221  213  Saint Pierre Miquelon           5
# 222  214               Anguilla           3
# 223  215                  China      84,951       +12       4,634
#
#                   6             7            8                 9  \
# 0    TotalRecovered  NewRecovered  ActiveCases  Serious,Critical
# 9         3,160,488       +12,408    2,528,464            16,729
# 10        2,709,638                    781,401             8,318
# 11        2,336,796       +56,896      710,697             8,944
# 12          770,639        +3,162      169,727             2,300
# ..              ...           ...          ...               ...
# 219               8                          1
# 220                                          7
# 221               1                          4
# 222               3                          0
# 223          79,895           +44          422                17
#
#                    10             11          12                13  \
# 0    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/\n1M pop\n
# 9              17,718            545  76,088,768           229,679
# 10             16,946            539  14,144,344            66,475
# 11              2,247             42  35,292,220            25,538
# 12              6,556            112  34,447,560           236,033
# ..                ...            ...         ...               ...
# 219                17              2
# 220
# 221               864
# 222               200                        662            44,069
# 223                59              3  90,410,000            62,814
#
#                  14             15                 16                  17  \
# 0        Population      Continent  1 Caseevery X ppl  1 Deathevery X ppl
# 9      331,282,824   North America                 56               1,835
# 10     212,776,644   South America                 59               1,854
# 11   1,381,937,641            Asia                445              23,954
# 12     145,943,650          Europe                153               8,908
# ..              ...            ...                ...                 ...
# 219        599,326          Africa             59,933             599,326
# 220
# 221          5,790   North America              1,158
# 222         15,022   North America              5,007
# 223  1,439,323,776            Asia             16,943             310,601
#
#                     18
# 0    1 Testevery X ppl
# 9                    4
# 10                  15
# 11                  39
# 12                   4
# ..                 ...
# 219
# 220
# 221
# 222                 23
# 223                 16
#
# [216 rows x 19 columns]

# %%
df.columns = df.iloc[0,:]
df.drop(index=0,inplace=True)

# %%
df
# Out:
# 0      #          Country,Other TotalCases NewCases TotalDeaths NewDeaths  \
# 9      1                    USA  5,869,507  +28,079    180,555       +381
# 10     2                 Brazil  3,605,783  +23,085    114,744       +467
# 11     3                  India  3,105,185  +61,749     57,692       +846
# 12     4                 Russia    956,749   +4,852     16,383        +73
# 13     5           South Africa    609,773   +2,728     13,059        +72
# ..   ...                    ...        ...      ...         ...       ...
# 219  211         Western Sahara         10                   1
# 220  212             MS Zaandam          9                   2
# 221  213  Saint Pierre Miquelon          5
# 222  214               Anguilla          3
# 223  215                  China     84,951      +12      4,634
#
# 0   TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# 9        3,160,488      +12,408   2,528,464           16,729           17,718
# 10       2,709,638                  781,401            8,318           16,946
# 11       2,336,796      +56,896     710,697            8,944            2,247
# 12         770,639       +3,162     169,727            2,300            6,556
# 13         506,470       +2,343      90,244              539           10,263
# ..             ...          ...         ...              ...              ...
# 219              8                        1                                17
# 220                                       7
# 221              1                        4                               864
# 222              3                        0                               200
# 223         79,895          +44         422               17               59
#
# 0   Deaths/1M pop  TotalTests Tests/\n1M pop\n      Population      Continent  \
# 9             545  76,088,768          229,679    331,282,824   North America
# 10            539  14,144,344           66,475    212,776,644   South America
# 11             42  35,292,220           25,538  1,381,937,641            Asia
# 12            112  34,447,560          236,033    145,943,650          Europe
# 13            220   3,553,425           59,808     59,414,253          Africa
# ..            ...         ...              ...             ...            ...
# 219             2                                     599,326          Africa
# 220
# 221                                                     5,790   North America
# 222                       662           44,069         15,022   North America
# 223             3  90,410,000           62,814  1,439,323,776            Asia
#
# 0   1 Caseevery X ppl 1 Deathevery X ppl 1 Testevery X ppl
# 9                  56              1,835                 4
# 10                 59              1,854                15
# 11                445             23,954                39
# 12                153              8,908                 4
# 13                 97              4,550                17
# ..                ...                ...               ...
# 219            59,933            599,326
# 220
# 221             1,158
# 222             5,007                                   23
# 223            16,943            310,601                16
#
# [215 rows x 19 columns]

# %%
df.set_index('#')
# Out:
# 0            Country,Other TotalCases NewCases TotalDeaths NewDeaths  \
# #
# 1                      USA  5,869,507  +28,079    180,555       +381
# 2                   Brazil  3,605,783  +23,085    114,744       +467
# 3                    India  3,105,185  +61,749     57,692       +846
# 4                   Russia    956,749   +4,852     16,383        +73
# 5             South Africa    609,773   +2,728     13,059        +72
# ..                     ...        ...      ...         ...       ...
# 211         Western Sahara         10                   1
# 212             MS Zaandam          9                   2
# 213  Saint Pierre Miquelon          5
# 214               Anguilla          3
# 215                  China     84,951      +12      4,634
#
# 0   TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# #
# 1        3,160,488      +12,408   2,528,464           16,729           17,718
# 2        2,709,638                  781,401            8,318           16,946
# 3        2,336,796      +56,896     710,697            8,944            2,247
# 4          770,639       +3,162     169,727            2,300            6,556
# 5          506,470       +2,343      90,244              539           10,263
# ..             ...          ...         ...              ...              ...
# 211              8                        1                                17
# 212                                       7
# 213              1                        4                               864
# 214              3                        0                               200
# 215         79,895          +44         422               17               59
#
# 0   Deaths/1M pop  TotalTests Tests/\n1M pop\n      Population      Continent  \
# #
# 1             545  76,088,768          229,679    331,282,824   North America
# 2             539  14,144,344           66,475    212,776,644   South America
# 3              42  35,292,220           25,538  1,381,937,641            Asia
# 4             112  34,447,560          236,033    145,943,650          Europe
# 5             220   3,553,425           59,808     59,414,253          Africa
# ..            ...         ...              ...             ...            ...
# 211             2                                     599,326          Africa
# 212
# 213                                                     5,790   North America
# 214                       662           44,069         15,022   North America
# 215             3  90,410,000           62,814  1,439,323,776            Asia
#
# 0   1 Caseevery X ppl 1 Deathevery X ppl 1 Testevery X ppl
# #
# 1                  56              1,835                 4
# 2                  59              1,854                15
# 3                 445             23,954                39
# 4                 153              8,908                 4
# 5                  97              4,550                17
# ..                ...                ...               ...
# 211            59,933            599,326
# 212
# 213             1,158
# 214             5,007                                   23
# 215            16,943            310,601                16
#
# [215 rows x 18 columns]

# %%
df.to_csv('Scraped Data 24-05-2020')
